# %%
#importing the libraries 
import numpy as np # linear algebra
import pandas as pd # data processing with CSV 
import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns
import scipy.stats as stats
import pylab
import warnings
import seaborn as sns
warnings.filterwarnings("ignore")

# %%
#Reading the Dataset and Displaying the head of it.
data=pd.read_csv("/content/drive/MyDrive/bank-additional-full.csv", sep = ";")
data.name = "data"
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
# To check duplicated values 
print(data.duplicated().value_counts())
# Out:
# False    41176
# True        12
# dtype: int64

# %%
data = data.drop_duplicates()

# %%
# Label encoder order is alphabetical
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
data['job']      = labelencoder_X.fit_transform(data['job']) 
data['marital']  = labelencoder_X.fit_transform(data['marital']) 
data['education']= labelencoder_X.fit_transform(data['education']) 
data['default']  = labelencoder_X.fit_transform(data['default']) 
data['housing']  = labelencoder_X.fit_transform(data['housing']) 
data['loan']     = labelencoder_X.fit_transform(data['loan']) 
data['month']     = labelencoder_X.fit_transform(data['month']) 
data['poutcome']     = labelencoder_X.fit_transform(data['poutcome'])
data['day_of_week']  = labelencoder_X.fit_transform(data['day_of_week'])
data['y']     = labelencoder_X.fit_transform(data['y'])

# %%
x = data.drop("y", axis=1)
y = data['y']

# %%
print(x.columns)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')

# %%
drop_list = [ 'marital', 'default', 'housing', 'loan',
       'contact', 'campaign',
       'previous',  'emp.var.rate']
x.drop(drop_list,axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42, stratify=y)
x_train, x_valid, y_train, y_valid = train_test_split(x, y, test_size=0.1, random_state=42, stratify=y)

# %%
x.head()
# Out:
#    age  job  education  month  day_of_week  duration  pdays  poutcome  \
# 0   56    3          0      6            1       261    999         1
# 1   57    7          3      6            1       149    999         1
# 2   37    7          3      6            1       226    999         1
# 3   40    0          1      6            1       151    999         1
# 4   56    7          3      6            1       307    999         1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 0          93.994          -36.4      4.857       5191.0
# 1          93.994          -36.4      4.857       5191.0
# 2          93.994          -36.4      4.857       5191.0
# 3          93.994          -36.4      4.857       5191.0
# 4          93.994          -36.4      4.857       5191.0

# %%
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-3.1.1-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.22.4)
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.10)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.65.0)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.10.4-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.9/212.9 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (23.1)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (2.0.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.2)
# Installing collected packages: Mako, colorlog, cmaes, alembic, optuna
# Successfully installed Mako-1.2.4 alembic-1.10.4 cmaes-0.9.1 colorlog-6.7.0 optuna-3.1.1

# %%
import lightgbm as lgb
import optuna
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold


# Define the objective function to minimize (in this case, validation loss)
def objective(trial):
    params = {
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 1),
        'num_leaves': trial.suggest_int('num_leaves', 2, 50),
        'max_depth': trial.suggest_int('max_depth', 2, 10),
        'subsample': trial.suggest_uniform('subsample', 0.1, 1),
        'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0.1, 1),
        'class_weight': trial.suggest_categorical('class_weight', [None, 'balanced', {0:1, 1:5}])
    }
    model = lgb.LGBMClassifier(**params)
    
    # Use k-fold cross-validation instead of a single validation set
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    accuracies = []
    for train_index, valid_index in kf.split(x):
        x_train, x_test = x.iloc[train_index], x.iloc[valid_index]
        y_train, y_test = y.iloc[train_index], y.iloc[valid_index]
        
        model.fit(x_train, y_train, eval_set=[(x_valid, y_valid)], early_stopping_rounds=10, verbose=False)
        y_pred = model.predict(x_valid)
        accuracy = accuracy_score(y_valid, y_pred)
        accuracies.append(accuracy)
        
    return 1 - sum(accuracies)/len(accuracies)

# Set up the Optuna study
study = optuna.create_study(direction='minimize')

# Run the study for a set number of trials
study.optimize(objective, n_trials=50)

# Get the best hyperparameters found
best_params = study.best_params

# Create the LightGBM model with the best parameters found
best_model = lgb.LGBMClassifier(**best_params)

# Fit the best model to the data
best_model.fit(x, y)

# Make predictions and evaluate
y_pred = best_model.predict(x)
cm = confusion_matrix(y, y_pred)
print(cm)

#confusion matrix visualization
import seaborn as sns
import matplotlib.pyplot as plt

f, ax=plt.subplots(figsize=(5,5))
sns.heatmap(cm,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()

# Print the best hyperparameters found
print("Best hyperparameters:", best_params)

# Make predictions and evaluate
y_pred = best_model.predict(x)
cm = confusion_matrix(y, y_pred)

# Calculate accuracy
accuracy = accuracy_score(y, y_pred)
print("Accuracy:", accuracy)

# Calculate false negative and false positive ratios
tn, fp, fn, tp = cm.ravel()
fnr = fn / (fn + tp)
fpr = fp / (fp + tn)
print("False negative ratio:", fnr)
print("False positive ratio:", fpr)
# Out:
# [I 2023-05-08 06:25:54,205] A new study created in memory with name: no-name-18cb9075-aec6-4996-a2f9-2aafec3e9d21
# [I 2023-05-08 06:25:57,874] Trial 0 finished with value: 0.16911121903836823 and parameters: {'learning_rate': 0.0017082392617680574, 'num_leaves': 27, 'max_depth': 3, 'subsample': 0.6292323742173338, 'colsample_bytree': 0.3794196194082543, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.16911121903836823.
# [I 2023-05-08 06:26:03,197] Trial 1 finished with value: 0.10004856726566302 and parameters: {'learning_rate': 0.13325116987462834, 'num_leaves': 35, 'max_depth': 7, 'subsample': 0.2040390217689095, 'colsample_bytree': 0.40818929875995147, 'class_weight': {0: 1, 1: 5}}. Best is trial 1 with value: 0.10004856726566302.
# [I 2023-05-08 06:26:05,011] Trial 2 finished with value: 0.09985429820301106 and parameters: {'learning_rate': 0.0059121910479181475, 'num_leaves': 8, 'max_depth': 6, 'subsample': 0.23490498625801925, 'colsample_bytree': 0.8710403280529347, 'class_weight': {0: 1, 1: 5}}. Best is trial 2 with value: 0.09985429820301106.
# [I 2023-05-08 06:26:06,675] Trial 3 finished with value: 0.11267605633802824 and parameters: {'learning_rate': 0.002087846179587362, 'num_leaves': 7, 'max_depth': 5, 'subsample': 0.9510809993792975, 'colsample_bytree': 0.8101548619269872, 'class_weight': {0: 1, 1: 5}}. Best is trial 2 with value: 0.09985429820301106.
# [I 2023-05-08 06:26:09,260] Trial 4 finished with value: 0.140019426906265 and parameters: {'learning_rate': 0.005261675179792252, 'num_leaves': 43, 'max_depth': 9, 'subsample': 0.7100683130909259, 'colsample_bytree': 0.5348939701968606, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.09985429820301106.
# [I 2023-05-08 06:26:12,098] Trial 5 finished with value: 0.1328800388538125 and parameters: {'learning_rate': 0.002560504297111269, 'num_leaves': 48, 'max_depth': 9, 'subsample': 0.34259356313826067, 'colsample_bytree': 0.9098177223177396, 'class_weight': 'balanced'}. Best is trial 2 with value: 0.09985429820301106.
# [I 2023-05-08 06:26:17,496] Trial 6 finished with value: 0.09441476444876162 and parameters: {'learning_rate': 0.0069660828303448104, 'num_leaves': 48, 'max_depth': 9, 'subsample': 0.884240570099207, 'colsample_bytree': 0.44948653832480356, 'class_weight': {0: 1, 1: 5}}. Best is trial 6 with value: 0.09441476444876162.
# [I 2023-05-08 06:26:19,511] Trial 7 finished with value: 0.11267605633802824 and parameters: {'learning_rate': 0.0033334322578189427, 'num_leaves': 34, 'max_depth': 5, 'subsample': 0.9371206294459201, 'colsample_bytree': 0.47146035115555396, 'class_weight': None}. Best is trial 6 with value: 0.09441476444876162.
# [I 2023-05-08 06:26:20,950] Trial 8 finished with value: 0.10024283632831477 and parameters: {'learning_rate': 0.02550496523568975, 'num_leaves': 13, 'max_depth': 4, 'subsample': 0.7960342708205509, 'colsample_bytree': 0.16423688463700553, 'class_weight': None}. Best is trial 6 with value: 0.09441476444876162.
# [I 2023-05-08 06:26:22,465] Trial 9 finished with value: 0.06998542982030109 and parameters: {'learning_rate': 0.5229751200246439, 'num_leaves': 7, 'max_depth': 5, 'subsample': 0.26349464977411036, 'colsample_bytree': 0.6946673492880112, 'class_weight': None}. Best is trial 9 with value: 0.06998542982030109.
# [I 2023-05-08 06:26:23,520] Trial 10 finished with value: 0.07969888295288974 and parameters: {'learning_rate': 0.8700558107101267, 'num_leaves': 18, 'max_depth': 2, 'subsample': 0.45011652838795874, 'colsample_bytree': 0.7158349313683334, 'class_weight': None}. Best is trial 9 with value: 0.06998542982030109.
# [I 2023-05-08 06:26:24,065] Trial 11 finished with value: 0.09907722195240398 and parameters: {'learning_rate': 0.9609003686646174, 'num_leaves': 18, 'max_depth': 2, 'subsample': 0.454925752333361, 'colsample_bytree': 0.6978535936177735, 'class_weight': None}. Best is trial 9 with value: 0.06998542982030109.
# [I 2023-05-08 06:26:25,267] Trial 12 finished with value: 0.08839242350655652 and parameters: {'learning_rate': 0.9903704277083341, 'num_leaves': 2, 'max_depth': 2, 'subsample': 0.4879995962761966, 'colsample_bytree': 0.6875607259578247, 'class_weight': None}. Best is trial 9 with value: 0.06998542982030109.
# [I 2023-05-08 06:26:30,326] Trial 13 finished with value: 0.059980573093734835 and parameters: {'learning_rate': 0.30464925710753504, 'num_leaves': 19, 'max_depth': 7, 'subsample': 0.36112665375482733, 'colsample_bytree': 0.9942776515956595, 'class_weight': None}. Best is trial 13 with value: 0.059980573093734835.
# [I 2023-05-08 06:26:32,310] Trial 14 finished with value: 0.05915492957746482 and parameters: {'learning_rate': 0.23406813286399683, 'num_leaves': 24, 'max_depth': 7, 'subsample': 0.10332080336692212, 'colsample_bytree': 0.9877859089132618, 'class_weight': None}. Best is trial 14 with value: 0.05915492957746482.
# [I 2023-05-08 06:26:34,137] Trial 15 finished with value: 0.05750364254492479 and parameters: {'learning_rate': 0.25660118767960627, 'num_leaves': 26, 'max_depth': 7, 'subsample': 0.1330210416505757, 'colsample_bytree': 0.9352588482427203, 'class_weight': None}. Best is trial 15 with value: 0.05750364254492479.
# [I 2023-05-08 06:26:36,246] Trial 16 finished with value: 0.06498300145701796 and parameters: {'learning_rate': 0.12365880862373274, 'num_leaves': 27, 'max_depth': 7, 'subsample': 0.17145562226696023, 'colsample_bytree': 0.9793940004641671, 'class_weight': None}. Best is trial 15 with value: 0.05750364254492479.
# [I 2023-05-08 06:26:38,270] Trial 17 finished with value: 0.055755220981058784 and parameters: {'learning_rate': 0.21405974230579758, 'num_leaves': 34, 'max_depth': 8, 'subsample': 0.13338976653381768, 'colsample_bytree': 0.9973177994833324, 'class_weight': None}. Best is trial 17 with value: 0.055755220981058784.
# [I 2023-05-08 06:26:43,751] Trial 18 finished with value: 0.06847984458474987 and parameters: {'learning_rate': 0.06844626493494416, 'num_leaves': 37, 'max_depth': 10, 'subsample': 0.11504876019657251, 'colsample_bytree': 0.7912310437516635, 'class_weight': None}. Best is trial 17 with value: 0.055755220981058784.
# [I 2023-05-08 06:26:46,302] Trial 19 finished with value: 0.1286061194754735 and parameters: {'learning_rate': 0.040013720420576056, 'num_leaves': 30, 'max_depth': 8, 'subsample': 0.306838718808672, 'colsample_bytree': 0.8779357627056353, 'class_weight': 'balanced'}. Best is trial 17 with value: 0.055755220981058784.
# [I 2023-05-08 06:26:48,458] Trial 20 finished with value: 0.04269062651772715 and parameters: {'learning_rate': 0.3464255655071284, 'num_leaves': 41, 'max_depth': 8, 'subsample': 0.154481803386626, 'colsample_bytree': 0.9065386668754027, 'class_weight': None}. Best is trial 20 with value: 0.04269062651772715.
# [I 2023-05-08 06:26:49,946] Trial 21 finished with value: 0.057697911607576535 and parameters: {'learning_rate': 0.3542462651143835, 'num_leaves': 41, 'max_depth': 8, 'subsample': 0.1003927168084406, 'colsample_bytree': 0.9156446012453999, 'class_weight': None}. Best is trial 20 with value: 0.04269062651772715.
# [I 2023-05-08 06:26:52,054] Trial 22 finished with value: 0.05386109762020408 and parameters: {'learning_rate': 0.22662456670557427, 'num_leaves': 40, 'max_depth': 8, 'subsample': 0.18813275178623134, 'colsample_bytree': 0.8088886490108977, 'class_weight': None}. Best is trial 20 with value: 0.04269062651772715.
# [I 2023-05-08 06:26:57,507] Trial 23 finished with value: 0.0542982030111705 and parameters: {'learning_rate': 0.14419086339354548, 'num_leaves': 43, 'max_depth': 10, 'subsample': 0.22124885717877543, 'colsample_bytree': 0.8249161741025253, 'class_weight': None}. Best is trial 20 with value: 0.04269062651772715.
# [I 2023-05-08 06:26:59,864] Trial 24 finished with value: 0.05760077707625055 and parameters: {'learning_rate': 0.12409848285062025, 'num_leaves': 42, 'max_depth': 10, 'subsample': 0.22991807666140054, 'colsample_bytree': 0.7934384275316138, 'class_weight': None}. Best is trial 20 with value: 0.04269062651772715.
# [I 2023-05-08 06:27:01,596] Trial 25 finished with value: 0.04594463331714427 and parameters: {'learning_rate': 0.4440044351301722, 'num_leaves': 45, 'max_depth': 10, 'subsample': 0.2868538375999133, 'colsample_bytree': 0.8311302086237593, 'class_weight': None}. Best is trial 20 with value: 0.04269062651772715.
# [I 2023-05-08 06:27:03,580] Trial 26 finished with value: 0.0421078193297717 and parameters: {'learning_rate': 0.5162183847562809, 'num_leaves': 50, 'max_depth': 9, 'subsample': 0.29598624840802384, 'colsample_bytree': 0.6372121455816575, 'class_weight': None}. Best is trial 26 with value: 0.0421078193297717.
# [I 2023-05-08 06:27:05,197] Trial 27 finished with value: 0.04711024769305483 and parameters: {'learning_rate': 0.5383114104440501, 'num_leaves': 49, 'max_depth': 9, 'subsample': 0.3874924499877323, 'colsample_bytree': 0.6206536514734354, 'class_weight': None}. Best is trial 26 with value: 0.0421078193297717.
# [I 2023-05-08 06:27:10,243] Trial 28 finished with value: 0.06580864497328798 and parameters: {'learning_rate': 0.5006139369479229, 'num_leaves': 46, 'max_depth': 10, 'subsample': 0.2800708335025036, 'colsample_bytree': 0.6143973876534011, 'class_weight': {0: 1, 1: 5}}. Best is trial 26 with value: 0.0421078193297717.
# [I 2023-05-08 06:27:12,234] Trial 29 finished with value: 0.07469645458960661 and parameters: {'learning_rate': 0.4705830956113443, 'num_leaves': 46, 'max_depth': 9, 'subsample': 0.5661264517724891, 'colsample_bytree': 0.7636175722187459, 'class_weight': 'balanced'}. Best is trial 26 with value: 0.0421078193297717.
# [I 2023-05-08 06:27:13,708] Trial 30 finished with value: 0.08878096163186022 and parameters: {'learning_rate': 0.6072341070872639, 'num_leaves': 39, 'max_depth': 10, 'subsample': 0.40688707140323893, 'colsample_bytree': 0.8558777172933434, 'class_weight': 'balanced'}. Best is trial 26 with value: 0.0421078193297717.
# [I 2023-05-08 06:27:15,788] Trial 31 finished with value: 0.04239922292374931 and parameters: {'learning_rate': 0.3957087040611032, 'num_leaves': 50, 'max_depth': 9, 'subsample': 0.3059621949821626, 'colsample_bytree': 0.6008255644395125, 'class_weight': None}. Best is trial 26 with value: 0.0421078193297717.
# [I 2023-05-08 06:27:17,922] Trial 32 finished with value: 0.04040796503156874 and parameters: {'learning_rate': 0.39057354313775844, 'num_leaves': 50, 'max_depth': 9, 'subsample': 0.3019058316468175, 'colsample_bytree': 0.6244985779701043, 'class_weight': None}. Best is trial 32 with value: 0.04040796503156874.
# [I 2023-05-08 06:27:20,573] Trial 33 finished with value: 0.04060223409422048 and parameters: {'learning_rate': 0.36958589434379446, 'num_leaves': 50, 'max_depth': 8, 'subsample': 0.3167870522648002, 'colsample_bytree': 0.6094506895648251, 'class_weight': None}. Best is trial 32 with value: 0.04040796503156874.
# [I 2023-05-08 06:27:25,278] Trial 34 finished with value: 0.06935405536668282 and parameters: {'learning_rate': 0.7087678954227595, 'num_leaves': 50, 'max_depth': 6, 'subsample': 0.32600048096941553, 'colsample_bytree': 0.5921041819517425, 'class_weight': {0: 1, 1: 5}}. Best is trial 32 with value: 0.04040796503156874.
# [I 2023-05-08 06:27:27,016] Trial 35 finished with value: 0.04298203011170476 and parameters: {'learning_rate': 0.6732071281142197, 'num_leaves': 50, 'max_depth': 9, 'subsample': 0.2495345415568243, 'colsample_bytree': 0.5749770525968587, 'class_weight': None}. Best is trial 32 with value: 0.04040796503156874.
# [I 2023-05-08 06:27:29,342] Trial 36 finished with value: 0.06750849927149116 and parameters: {'learning_rate': 0.37286130590747485, 'num_leaves': 45, 'max_depth': 9, 'subsample': 0.3424164482503148, 'colsample_bytree': 0.5338583106673467, 'class_weight': {0: 1, 1: 5}}. Best is trial 32 with value: 0.04040796503156874.
# [I 2023-05-08 06:27:31,680] Trial 37 finished with value: 0.06197183098591563 and parameters: {'learning_rate': 0.1726616207533453, 'num_leaves': 47, 'max_depth': 6, 'subsample': 0.3960606833096041, 'colsample_bytree': 0.638438110388761, 'class_weight': None}. Best is trial 32 with value: 0.04040796503156874.
# [I 2023-05-08 06:27:37,201] Trial 38 finished with value: 0.08440990772219537 and parameters: {'learning_rate': 0.3259949735458288, 'num_leaves': 50, 'max_depth': 8, 'subsample': 0.29428247079083825, 'colsample_bytree': 0.5320331771784079, 'class_weight': 'balanced'}. Best is trial 32 with value: 0.04040796503156874.
# [I 2023-05-08 06:27:38,197] Trial 39 finished with value: 0.06498300145701807 and parameters: {'learning_rate': 0.7129633232184925, 'num_leaves': 37, 'max_depth': 9, 'subsample': 0.17985589680774677, 'colsample_bytree': 0.4901839069888583, 'class_weight': None}. Best is trial 32 with value: 0.04040796503156874.
# [I 2023-05-08 06:27:40,779] Trial 40 finished with value: 0.09859154929577463 and parameters: {'learning_rate': 0.08985696632862528, 'num_leaves': 44, 'max_depth': 8, 'subsample': 0.21082716197674556, 'colsample_bytree': 0.6473509810162775, 'class_weight': {0: 1, 1: 5}}. Best is trial 32 with value: 0.04040796503156874.
# [I 2023-05-08 06:27:43,105] Trial 41 finished with value: 0.03812530354541044 and parameters: {'learning_rate': 0.3225391869360439, 'num_leaves': 47, 'max_depth': 9, 'subsample': 0.2700359243101899, 'colsample_bytree': 0.7452842843766571, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:27:45,498] Trial 42 finished with value: 0.04851869839728029 and parameters: {'learning_rate': 0.1869969764348896, 'num_leaves': 48, 'max_depth': 9, 'subsample': 0.25181312421960766, 'colsample_bytree': 0.7517692818172286, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:27:49,216] Trial 43 finished with value: 0.04541039339485187 and parameters: {'learning_rate': 0.2683766100053704, 'num_leaves': 50, 'max_depth': 9, 'subsample': 0.3205468981148027, 'colsample_bytree': 0.6569977203203633, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:27:52,897] Trial 44 finished with value: 0.04142787761049038 and parameters: {'learning_rate': 0.4415174075826165, 'num_leaves': 47, 'max_depth': 9, 'subsample': 0.3611459560743764, 'colsample_bytree': 0.5694219147395387, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:27:53,962] Trial 45 finished with value: 0.061923263720252586 and parameters: {'learning_rate': 0.6689143264544729, 'num_leaves': 47, 'max_depth': 10, 'subsample': 0.363180397668327, 'colsample_bytree': 0.5634955950725753, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:27:54,700] Trial 46 finished with value: 0.09378338999514324 and parameters: {'learning_rate': 0.8225441541951222, 'num_leaves': 44, 'max_depth': 3, 'subsample': 0.43824185431114177, 'colsample_bytree': 0.733233139163918, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:27:55,319] Trial 47 finished with value: 0.11058766391452168 and parameters: {'learning_rate': 0.987265343919024, 'num_leaves': 47, 'max_depth': 8, 'subsample': 0.24936741259875503, 'colsample_bytree': 0.6646082533979278, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:27:57,402] Trial 48 finished with value: 0.05016998542982043 and parameters: {'learning_rate': 0.29572028919863197, 'num_leaves': 31, 'max_depth': 7, 'subsample': 0.3538756064161114, 'colsample_bytree': 0.7167323520007218, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:27:59,315] Trial 49 finished with value: 0.048664400194268986 and parameters: {'learning_rate': 0.48686045464809946, 'num_leaves': 38, 'max_depth': 9, 'subsample': 0.27926383819791606, 'colsample_bytree': 0.413068453615405, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:28:01,201] Trial 50 finished with value: 0.12156386595434676 and parameters: {'learning_rate': 0.1840551402248149, 'num_leaves': 12, 'max_depth': 8, 'subsample': 0.4829143432872788, 'colsample_bytree': 0.6814408938514818, 'class_weight': 'balanced'}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:28:06,333] Trial 51 finished with value: 0.04201068479844583 and parameters: {'learning_rate': 0.40059946459400403, 'num_leaves': 48, 'max_depth': 9, 'subsample': 0.31278957763758236, 'colsample_bytree': 0.5983091369801932, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:28:08,767] Trial 52 finished with value: 0.042496357455075406 and parameters: {'learning_rate': 0.26559330023771416, 'num_leaves': 48, 'max_depth': 9, 'subsample': 0.21232941262056482, 'colsample_bytree': 0.62572356619013, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:28:10,628] Trial 53 finished with value: 0.046284604176784816 and parameters: {'learning_rate': 0.41522314235962393, 'num_leaves': 43, 'max_depth': 10, 'subsample': 0.3276880645311128, 'colsample_bytree': 0.5556854708850929, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:28:12,243] Trial 54 finished with value: 0.047935891209325066 and parameters: {'learning_rate': 0.5481818615789448, 'num_leaves': 45, 'max_depth': 9, 'subsample': 0.3755625162271125, 'colsample_bytree': 0.6896314495538297, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:28:14,082] Trial 55 finished with value: 0.06119475473530844 and parameters: {'learning_rate': 0.30317647088796557, 'num_leaves': 21, 'max_depth': 7, 'subsample': 0.27139103835707873, 'colsample_bytree': 0.5066382746366521, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:28:19,489] Trial 56 finished with value: 0.05492957746478877 and parameters: {'learning_rate': 0.23392030656566276, 'num_leaves': 48, 'max_depth': 8, 'subsample': 0.42009626483513873, 'colsample_bytree': 0.4576461182067458, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:28:21,741] Trial 57 finished with value: 0.042933462846041714 and parameters: {'learning_rate': 0.3709617072937217, 'num_leaves': 41, 'max_depth': 10, 'subsample': 0.3560485350288174, 'colsample_bytree': 0.5877062680409714, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:28:22,355] Trial 58 finished with value: 0.08950947061680414 and parameters: {'learning_rate': 0.8165681864632465, 'num_leaves': 35, 'max_depth': 9, 'subsample': 0.16519498312354186, 'colsample_bytree': 0.6552919542508767, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:28:24,158] Trial 59 finished with value: 0.0628946090335113 and parameters: {'learning_rate': 0.5483340183545292, 'num_leaves': 46, 'max_depth': 4, 'subsample': 0.3087354370521044, 'colsample_bytree': 0.7013201872425919, 'class_weight': None}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:28:26,591] Trial 60 finished with value: 0.08989800874210785 and parameters: {'learning_rate': 0.15899804405262574, 'num_leaves': 43, 'max_depth': 8, 'subsample': 0.20538483908410765, 'colsample_bytree': 0.6081019200457806, 'class_weight': {0: 1, 1: 5}}. Best is trial 41 with value: 0.03812530354541044.
# [I 2023-05-08 06:28:32,064] Trial 61 finished with value: 0.0354055366682855 and parameters: {'learning_rate': 0.4013897484278915, 'num_leaves': 49, 'max_depth': 9, 'subsample': 0.3093387147569032, 'colsample_bytree': 0.5896766309292637, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:28:34,248] Trial 62 finished with value: 0.03929091792132111 and parameters: {'learning_rate': 0.4276667529186679, 'num_leaves': 48, 'max_depth': 9, 'subsample': 0.2408790152775731, 'colsample_bytree': 0.5582549205486917, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:28:36,591] Trial 63 finished with value: 0.0477416221466731 and parameters: {'learning_rate': 0.22412726719173856, 'num_leaves': 48, 'max_depth': 10, 'subsample': 0.25123187665950947, 'colsample_bytree': 0.5191657224119148, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:28:38,702] Trial 64 finished with value: 0.045118989800874254 and parameters: {'learning_rate': 0.33379006489693247, 'num_leaves': 46, 'max_depth': 9, 'subsample': 0.2289814855818797, 'colsample_bytree': 0.5484184998538418, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:28:40,880] Trial 65 finished with value: 0.04215638659543475 and parameters: {'learning_rate': 0.40930445180597086, 'num_leaves': 48, 'max_depth': 8, 'subsample': 0.38086333834334374, 'colsample_bytree': 0.5727244800569646, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:28:44,668] Trial 66 finished with value: 0.08834385624089358 and parameters: {'learning_rate': 0.2718217479773307, 'num_leaves': 2, 'max_depth': 9, 'subsample': 0.34543263815746694, 'colsample_bytree': 0.594412870137218, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:28:46,659] Trial 67 finished with value: 0.053569694026226244 and parameters: {'learning_rate': 0.6251023286939671, 'num_leaves': 44, 'max_depth': 10, 'subsample': 0.2846176569056136, 'colsample_bytree': 0.4940104255237171, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:28:48,990] Trial 68 finished with value: 0.03836813987372523 and parameters: {'learning_rate': 0.4314833356976758, 'num_leaves': 49, 'max_depth': 8, 'subsample': 0.14894317430124493, 'colsample_bytree': 0.5515850652444082, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:28:51,375] Trial 69 finished with value: 0.10237979601748426 and parameters: {'learning_rate': 0.20491389315376013, 'num_leaves': 42, 'max_depth': 7, 'subsample': 0.1362444760880277, 'colsample_bytree': 0.54276465476855, 'class_weight': 'balanced'}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:28:52,099] Trial 70 finished with value: 0.08474987858183591 and parameters: {'learning_rate': 0.7892769698021451, 'num_leaves': 49, 'max_depth': 8, 'subsample': 0.18932644872564397, 'colsample_bytree': 0.4702631739588212, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:28:53,981] Trial 71 finished with value: 0.04633317144244775 and parameters: {'learning_rate': 0.4260080342797256, 'num_leaves': 46, 'max_depth': 9, 'subsample': 0.24061529512020574, 'colsample_bytree': 0.5805530667398928, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:28:58,564] Trial 72 finished with value: 0.04341913550267118 and parameters: {'learning_rate': 0.44955122840763584, 'num_leaves': 49, 'max_depth': 9, 'subsample': 0.3184857096017697, 'colsample_bytree': 0.6224639007027489, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:01,289] Trial 73 finished with value: 0.043564837299659986 and parameters: {'learning_rate': 0.3247274399441962, 'num_leaves': 47, 'max_depth': 8, 'subsample': 0.15674515230941224, 'colsample_bytree': 0.5229879423941753, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:02,680] Trial 74 finished with value: 0.05250121418164144 and parameters: {'learning_rate': 0.5915430243508013, 'num_leaves': 45, 'max_depth': 10, 'subsample': 0.27037425951727795, 'colsample_bytree': 0.5601273214760363, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:04,867] Trial 75 finished with value: 0.04133074307916473 and parameters: {'learning_rate': 0.3666971256915893, 'num_leaves': 49, 'max_depth': 9, 'subsample': 0.19053322883430435, 'colsample_bytree': 0.6708210288004096, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:07,405] Trial 76 finished with value: 0.03987372510927645 and parameters: {'learning_rate': 0.2853123964693452, 'num_leaves': 50, 'max_depth': 8, 'subsample': 0.18200281919715067, 'colsample_bytree': 0.6272046348225703, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:13,084] Trial 77 finished with value: 0.0913064594463332 and parameters: {'learning_rate': 0.14898870663103295, 'num_leaves': 50, 'max_depth': 7, 'subsample': 0.13180897815671844, 'colsample_bytree': 0.6630241232276906, 'class_weight': {0: 1, 1: 5}}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:15,390] Trial 78 finished with value: 0.05526954832442921 and parameters: {'learning_rate': 0.24907176442710852, 'num_leaves': 49, 'max_depth': 6, 'subsample': 0.18908662023265563, 'colsample_bytree': 0.6375123236235543, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:17,682] Trial 79 finished with value: 0.04278776104905302 and parameters: {'learning_rate': 0.33300986553189976, 'num_leaves': 50, 'max_depth': 8, 'subsample': 0.21082999418163267, 'colsample_bytree': 0.7251327985557902, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:19,162] Trial 80 finished with value: 0.08008742107819322 and parameters: {'learning_rate': 0.21914152165864972, 'num_leaves': 4, 'max_depth': 8, 'subsample': 0.16942165095777287, 'colsample_bytree': 0.6855638334747785, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:20,639] Trial 81 finished with value: 0.051724137931034475 and parameters: {'learning_rate': 0.5163571923165831, 'num_leaves': 47, 'max_depth': 9, 'subsample': 0.262709888657874, 'colsample_bytree': 0.6208000360534686, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:23,130] Trial 82 finished with value: 0.042496357455075184 and parameters: {'learning_rate': 0.28910157880784976, 'num_leaves': 49, 'max_depth': 9, 'subsample': 0.23442797560734896, 'colsample_bytree': 0.6066116390265763, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:28,120] Trial 83 finished with value: 0.04201068479844583 and parameters: {'learning_rate': 0.4703568500865445, 'num_leaves': 46, 'max_depth': 8, 'subsample': 0.19854944022649115, 'colsample_bytree': 0.5672730381530374, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:29,527] Trial 84 finished with value: 0.05468674113647398 and parameters: {'learning_rate': 0.7055064148046779, 'num_leaves': 44, 'max_depth': 9, 'subsample': 0.23253420376367873, 'colsample_bytree': 0.6706492797432388, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:31,842] Trial 85 finished with value: 0.08144730451675586 and parameters: {'learning_rate': 0.36794212951317556, 'num_leaves': 42, 'max_depth': 8, 'subsample': 0.11359791771195987, 'colsample_bytree': 0.6419995714511298, 'class_weight': 'balanced'}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:33,370] Trial 86 finished with value: 0.05376396308887821 and parameters: {'learning_rate': 0.6067576947584296, 'num_leaves': 47, 'max_depth': 10, 'subsample': 0.29177413490328974, 'colsample_bytree': 0.704254517143207, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:35,744] Trial 87 finished with value: 0.05522098105876638 and parameters: {'learning_rate': 0.1788338513740393, 'num_leaves': 49, 'max_depth': 7, 'subsample': 0.14914996110174567, 'colsample_bytree': 0.5828136956964702, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:36,324] Trial 88 finished with value: 0.11282175813501694 and parameters: {'learning_rate': 0.9914865123046452, 'num_leaves': 30, 'max_depth': 9, 'subsample': 0.1765327351049328, 'colsample_bytree': 0.5360823410735239, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:41,591] Trial 89 finished with value: 0.04905293831957258 and parameters: {'learning_rate': 0.2674948597747801, 'num_leaves': 45, 'max_depth': 9, 'subsample': 0.3334230544167388, 'colsample_bytree': 0.5051604909919807, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:43,654] Trial 90 finished with value: 0.08402136959689166 and parameters: {'learning_rate': 0.4502587508385797, 'num_leaves': 50, 'max_depth': 5, 'subsample': 0.26573417611462136, 'colsample_bytree': 0.6711345641921181, 'class_weight': {0: 1, 1: 5}}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:45,743] Trial 91 finished with value: 0.0431762991743565 and parameters: {'learning_rate': 0.37398706745539273, 'num_leaves': 48, 'max_depth': 9, 'subsample': 0.30543772512247674, 'colsample_bytree': 0.6225058145634028, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:47,710] Trial 92 finished with value: 0.04473045167557077 and parameters: {'learning_rate': 0.4001950022634318, 'num_leaves': 49, 'max_depth': 9, 'subsample': 0.2180523189104184, 'colsample_bytree': 0.6052935552270072, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:49,402] Trial 93 finished with value: 0.04657600777076243 and parameters: {'learning_rate': 0.5457806359925145, 'num_leaves': 47, 'max_depth': 8, 'subsample': 0.2912218537217149, 'colsample_bytree': 0.5911852769115551, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:54,203] Trial 94 finished with value: 0.0655658086449733 and parameters: {'learning_rate': 0.31117302853921264, 'num_leaves': 15, 'max_depth': 9, 'subsample': 0.33545637824606583, 'colsample_bytree': 0.6376021817781546, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:55,116] Trial 95 finished with value: 0.07275376396308886 and parameters: {'learning_rate': 0.7540984069145141, 'num_leaves': 48, 'max_depth': 10, 'subsample': 0.2576574859416155, 'colsample_bytree': 0.5577638179053552, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:56,674] Trial 96 finished with value: 0.04895580378824671 and parameters: {'learning_rate': 0.494122427942007, 'num_leaves': 46, 'max_depth': 9, 'subsample': 0.364591777601663, 'colsample_bytree': 0.5984104114651372, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:29:58,760] Trial 97 finished with value: 0.04443904808159316 and parameters: {'learning_rate': 0.3559301606639588, 'num_leaves': 45, 'max_depth': 8, 'subsample': 0.22980092501811678, 'colsample_bytree': 0.7461998397314167, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:30:01,170] Trial 98 finished with value: 0.045556095191840784 and parameters: {'learning_rate': 0.23760730478536954, 'num_leaves': 50, 'max_depth': 10, 'subsample': 0.31555393406206406, 'colsample_bytree': 0.549334077342152, 'class_weight': None}. Best is trial 61 with value: 0.0354055366682855.
# [I 2023-05-08 06:30:03,550] Trial 99 finished with value: 0.10058280718795543 and parameters: {'learning_rate': 0.19506620122567342, 'num_leaves': 40, 'max_depth': 9, 'subsample': 0.4016625499453521, 'colsample_bytree': 0.5761492299667735, 'class_weight': 'balanced'}. Best is trial 61 with value: 0.0354055366682855.
# [[35998   539]
#  [ 1051  3588]]
# Best hyperparameters: {'learning_rate': 0.4013897484278915, 'num_leaves': 49, 'max_depth': 9, 'subsample': 0.3093387147569032, 'colsample_bytree': 0.5896766309292637, 'class_weight': None}
# Accuracy: 0.9613852729745482
# False negative ratio: 0.22655744772580297
# False positive ratio: 0.014752169034129787
